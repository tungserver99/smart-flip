# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip

# %%
# !pip install lm-eval
# Out:
# Collecting lm-eval
#   Downloading lm_eval-0.4.11-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from lm-eval) (4.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lm-eval) (2.0.2)
# Collecting evaluate>=0.4.0 (from lm-eval)
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from lm-eval) (3.1.6)
# Collecting jsonlines (from lm-eval)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting pytablewriter (from lm-eval)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting rouge-score>=0.0.4 (from lm-eval)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm-eval)
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from lm-eval) (1.6.1)
# Collecting sqlitedict (from lm-eval)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zstandard in /usr/local/lib/python3.12/dist-packages (from lm-eval) (0.25.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from lm-eval) (0.3.8)
# Collecting word2number (from lm-eval)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from lm-eval) (10.8.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lm-eval) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (18.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (1.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm-eval) (6.0.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm-eval) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm-eval) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm-eval) (1.17.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm-eval)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm-eval) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm-eval) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm-eval)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm-eval) (6.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm-eval) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm-eval) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm-eval) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->lm-eval) (3.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->lm-eval) (25.4.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.12/dist-packages (from pytablewriter->lm-eval) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter->lm-eval)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm-eval)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm-eval)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm-eval)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm-eval)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm-eval)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (0.24.1)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm-eval) (5.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm-eval) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm-eval) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm-eval) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm-eval) (2026.2.25)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm-eval) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm-eval) (2025.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score>=0.0.4->lm-eval) (8.3.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.16.0->lm-eval) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm-eval) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets>=2.16.0->lm-eval) (0.1.2)
# Downloading lm_eval-0.4.11-py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 144.1 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.4 MB/s eta 0:00:00
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 13.6 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.4 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: rouge-score, sqlitedict, word2number
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=f7973c8ea5e695fbb49a4ffea26c1f1fdf6bf4b5139436e3db3c1b1e6d343184
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=d6e96721f88b5de8ed010339249cbaefdc70001e373eb24f76337d877bc954c2
#   Stored in directory: /root/.cache/pip/wheels/7a/6f/21/fc016aef45ffcabe27129a2252f061387cbf278d2086225a64
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=b7a73d52bac6ce72a0057696612135a2b8bc5bbb2f525e650b0de2178a935702
#   Stored in directory: /root/.cache/pip/wheels/5b/79/fb/d25928e599c7e11fe4e00d32048cd74933f34a74c633d2aea6
# Successfully built rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, tcolorpy, portalocker, pathvalidate, mbstrdecoder, jsonlines, colorama, typepy, sacrebleu, rouge-score, DataProperty, tabledata, pytablewriter, evaluate, lm-eval
# Successfully installed DataProperty-1.1.0 colorama-0.4.6 evaluate-0.4.6 jsonlines-4.0.0 lm-eval-0.4.11 mbstrdecoder-1.1.4 pathvalidate-3.3.1 portalocker-3.2.0 pytablewriter-1.2.1 rouge-score-0.1.2 sacrebleu-2.6.0 sqlitedict-2.1.0 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4 word2number-1.1

# %%
# !python main.py float_model --model-path mistralai/Mistral-7B-v0.3 --run-name float_eval
# !python main.py raw_quantize --model-path mistralai/Mistral-7B-v0.3 --origin-method awq --run-name awq_raw_run
# !python main.py flip_quantize --model-path mistralai/Mistral-7B-v0.3 --origin-method awq --run-name awq_flip_run
# !MODEL_PATH=mistralai/Mistral-7B-v0.3 bash scripts/bash/run_float_model.sh
# !MODEL_PATH=mistralai/Mistral-7B-v0.3 bash scripts/bash/run_raw_quantize.sh
# !MODEL_PATH=mistralai/Mistral-7B-v0.3 bash scripts/bash/run_flip_quantize.sh
# Out:
# Evaluating float_model on WikiText-2...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:34<00:00,  8.37it/s, Materializing param=model.norm.weight]
#
# Evaluating float_model on C4...
# Loading weights: 100% 291/291 [00:04<00:00, 63.87it/s, Materializing param=model.norm.weight]
#
# Running lm-eval for float_model on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa...
# Loading weights: 100% 291/291 [00:04<00:00, 62.28it/s, Materializing param=model.norm.weight]
# [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# [Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 500/500 [00:00<00:00, 552.93it/s]
# 100% 277/277 [00:00<00:00, 1739.50it/s]
# 100% 3270/3270 [00:01<00:00, 1770.85it/s]
# 100% 1267/1267 [00:00<00:00, 68747.52it/s]
# 100% 1838/1838 [00:02<00:00, 653.57it/s]
# 100% 10042/10042 [00:08<00:00, 1156.81it/s]
# 100% 1172/1172 [00:02<00:00, 466.60it/s]
# 100% 2376/2376 [00:05<00:00, 474.00it/s]
# Running loglikelihood requests:   0% 0/69660 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Determined largest batch size: 51
# Running loglikelihood requests: 100% 69660/69660 [07:19<00:00, 158.60it/s]
#
# Saved evaluation results to results/eval/float_eval.json
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:03<00:00, 78.29it/s, Materializing param=model.norm.weight]
#
# [C4 Calibration Data - Optimized]
#   Samples: 128
#   Sequence length: 2048 tokens
#   Seed: 42
#   Loading from cache: data/cache/calibration/c4_calib_n128_len2048_seed42_tensorsFalse.pkl
#
# [AWQ Quantizer XL Initialized]
#   Config: {'bits': 4, 'n_grid': 20, 'group_size': 128, 'max_tokens_per_sample': 2048, 'layer_batch_size': 16, 'lmhead_chunks': 4}
#   Post correction: none
#
# ================================================================================
# Batched Sequential Quantization
# ================================================================================
#   Strategy: Process 16 layers per batch
#   Initial System RAM: 3.2%
#
# [Batch 1/15] Layers 0-15
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 2/15] Layers 16-31
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 3/15] Layers 32-47
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 4/15] Layers 48-63
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 5/15] Layers 64-79
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 6/15] Layers 80-95
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 7/15] Layers 96-111
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 8/15] Layers 112-127
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 9/15] Layers 128-143
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 10/15] Layers 144-159
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 11/15] Layers 160-175
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 12/15] Layers 176-191
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 13/15] Layers 192-207
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 14/15] Layers 208-223
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 15/15] Layers 224-224
#   Calibrating 1 layers...
#   Quantizing 1 layers...
#
# ================================================================================
# Quantization Complete
#   Total layers quantized: 225/225
# ================================================================================
# Writing model shards: 100% 1/1 [01:00<00:00, 60.69s/it]
#
# Saved awq_raw model to results/models/awq_raw/awq_raw_run
#
# Evaluating raw_quantize on WikiText-2...
# Loading weights: 100% 291/291 [02:36<00:00,  1.85it/s, Materializing param=model.norm.weight]
#
# Evaluating raw_quantize on C4...
# Loading weights: 100% 291/291 [00:06<00:00, 44.62it/s, Materializing param=model.norm.weight]
#
# Running lm-eval for raw_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa...
# Loading weights: 100% 291/291 [00:06<00:00, 43.67it/s, Materializing param=model.norm.weight]
# [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# [Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 500/500 [00:00<00:00, 570.49it/s]
# 100% 277/277 [00:00<00:00, 1767.62it/s]
# 100% 3270/3270 [00:01<00:00, 1809.28it/s]
# 100% 1267/1267 [00:00<00:00, 68177.75it/s]
# 100% 1838/1838 [00:02<00:00, 664.80it/s]
# 100% 10042/10042 [00:08<00:00, 1163.74it/s]
# 100% 1172/1172 [00:02<00:00, 471.70it/s]
# 100% 2376/2376 [00:04<00:00, 476.45it/s]
# Running loglikelihood requests:   0% 0/69660 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Determined largest batch size: 51
# Running loglikelihood requests: 100% 69660/69660 [07:15<00:00, 159.79it/s]
#
# Saved evaluation results to results/eval/awq_raw_run.json
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:21<00:00, 13.48it/s, Materializing param=model.norm.weight]
#
# [C4 Calibration Data - Optimized]
#   Samples: 128
#   Sequence length: 2048 tokens
#   Seed: 42
#   Loading from cache: data/cache/calibration/c4_calib_n128_len2048_seed42_tensorsFalse.pkl
#
# [AWQ Quantizer XL Initialized]
#   Config: {'bits': 4, 'n_grid': 20, 'group_size': 128, 'max_tokens_per_sample': 2048, 'layer_batch_size': 16, 'lmhead_chunks': 4}
#   Post correction: SmartFlipCorrection
#
# ================================================================================
# Batched Sequential Quantization
# ================================================================================
#   Strategy: Process 16 layers per batch
#   Initial System RAM: 3.2%
#
# [Batch 1/15] Layers 0-15
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 2/15] Layers 16-31
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 3/15] Layers 32-47
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 4/15] Layers 48-63
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 5/15] Layers 64-79
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 6/15] Layers 80-95
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 7/15] Layers 96-111
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 8/15] Layers 112-127
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 9/15] Layers 128-143
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 10/15] Layers 144-159
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 11/15] Layers 160-175
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 12/15] Layers 176-191
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 13/15] Layers 192-207
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 14/15] Layers 208-223
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 15/15] Layers 224-224
#   Calibrating 1 layers...
#   Quantizing 1 layers...
#
# ================================================================================
# Quantization Complete
#   Total layers quantized: 225/225
# ================================================================================
# Writing model shards: 100% 1/1 [00:59<00:00, 59.88s/it]
#
# Saved awq_flip model to results/models/awq_flip/awq_flip_run
#
# Evaluating flip_quantize on WikiText-2...
# Loading weights: 100% 291/291 [02:45<00:00,  1.76it/s, Materializing param=model.norm.weight]
#
# Evaluating flip_quantize on C4...
# Loading weights: 100% 291/291 [00:06<00:00, 46.38it/s, Materializing param=model.norm.weight]
#
# Running lm-eval for flip_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa...
# Loading weights: 100% 291/291 [00:06<00:00, 44.49it/s, Materializing param=model.norm.weight]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# [Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 500/500 [00:00<00:00, 567.32it/s]
# 100% 277/277 [00:00<00:00, 1763.77it/s]
# 100% 3270/3270 [00:01<00:00, 1791.86it/s]
# 100% 1267/1267 [00:00<00:00, 70852.94it/s]
# 100% 1838/1838 [00:02<00:00, 659.27it/s]
# 100% 10042/10042 [00:08<00:00, 1163.70it/s]
# 100% 1172/1172 [00:02<00:00, 476.72it/s]
# 100% 2376/2376 [00:04<00:00, 480.20it/s]
# Running loglikelihood requests:   0% 0/69660 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Determined largest batch size: 51
# Running loglikelihood requests: 100% 69660/69660 [07:14<00:00, 160.15it/s]
#
# Saved evaluation results to results/eval/awq_flip_run.json

# %%
from pathlib import Path
from src.smart_flip.evaluation.lm_eval import LMEvalHarnessRunner

root = Path("/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip")

flip_candidates = sorted((root / "results/models/awq_flip").glob("awq_flip_run*"))
raw_candidates = sorted((root / "results/models/awq_raw").glob("awq_raw_run*"))

print("flip candidates:")
for p in flip_candidates:
    print(" -", p)

print("raw candidates:")
for p in raw_candidates:
    print(" -", p)

flip_path = flip_candidates[-1]
raw_path = raw_candidates[-1]

print("\nchosen flip:", flip_path, "exists:", flip_path.exists())
print("chosen raw :", raw_path, "exists:", raw_path.exists())

runner = LMEvalHarnessRunner(
    tasks=["lambada_openai"],
    output_dir=str(root / "results/eval/tmp"),
    run_name="tmp_lambada_saved_models",
)

results = runner.run({
    "awq_flip": str(flip_path.resolve()),
    "awq_raw": str(raw_path.resolve()),
})

results

# %%
from pathlib import Path
from src.smart_flip.evaluation.lm_eval import LMEvalHarnessRunner

root = Path("/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip")

runner = LMEvalHarnessRunner(
    tasks=["lambada_openai"],
    output_dir=str(root / "results/eval/tmp"),
    run_name="tmp_lambada_float_model",
)

results = runner.run({
    "float_model": "mistralai/Mistral-7B-v0.3",
})

results

# %%
# !sed -i 's/\r$//' scripts/bash/run_llama_grid.sh
# !sed -i 's/\r$//' scripts/bash/run_float_model.sh
# !sed -i 's/\r$//' scripts/bash/run_raw_quantize.sh
# !sed -i 's/\r$//' scripts/bash/run_flip_quantize.sh

# %%
# !hf auth login
# Out:
# A new version of huggingface_hub (1.8.0) is available! You are using version 1.7.1.
# To update, run: pip install -U huggingface_hub
#
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? [y/N]: N
# Token is valid (permission: fineGrained).
# The token `fptai` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `fptai`

# %%
# !bash scripts/bash/run_llama_grid.sh
# Out:
# ==> float_model :: meta-llama/Meta-Llama-3.1-8B
#
# Evaluating float_model on WikiText-2...
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 23.9kB [00:00, 53.0MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 16.1G/16.1G [00:41<00:00, 469MB/s]
# Fetching 4 files: 100% 4/4 [00:41<00:00, 10.46s/it]
# Download complete: 100% 16.1G/16.1G [00:41<00:00, 383MB/s]
# Loading weights: 100% 291/291 [00:05<00:00, 57.88it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 185/185 [00:00<00:00, 841kB/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (288936 > 131072). Running this sequence through the model will result in indexing errors
#
# Evaluating float_model on C4...
# Loading weights: 100% 291/291 [00:04<00:00, 59.27it/s, Materializing param=model.norm.weight]
# Token indices sequence length is longer than the specified maximum sequence length for this model (291380 > 131072). Running this sequence through the model will result in indexing errors
#
# Running lm-eval for float_model on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# Loading weights: 100% 291/291 [00:05<00:00, 57.62it/s, Materializing param=model.norm.weight]
# README.md: 9.00kB [00:00, 5.28MB/s]
# ARC-Easy/train-00000-of-00001.parquet: 100% 331k/331k [00:01<00:00, 327kB/s]
# ARC-Easy/test-00000-of-00001.parquet: 100% 346k/346k [00:00<00:00, 844kB/s]
# ARC-Easy/validation-00000-of-00001.parqu(…): 100% 86.1k/86.1k [00:00<00:00, 209kB/s]
# Generating train split: 100% 2251/2251 [00:00<00:00, 77971.21 examples/s]
# Generating test split: 100% 2376/2376 [00:00<00:00, 418655.11 examples/s]
# Generating validation split: 100% 570/570 [00:00<00:00, 200432.03 examples/s]
# ARC-Challenge/train-00000-of-00001.parqu(…): 100% 190k/190k [00:00<00:00, 463kB/s]
# ARC-Challenge/test-00000-of-00001.parque(…): 100% 204k/204k [00:00<00:00, 496kB/s]
# ARC-Challenge/validation-00000-of-00001.(…): 100% 55.7k/55.7k [00:00<00:00, 136kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 218156.84 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 270689.66 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 114351.86 examples/s]
# README.md: 7.02kB [00:00, 16.3MB/s]
# data/train-00000-of-00001.parquet: 100% 24.4M/24.4M [00:00<00:00, 59.3MB/s]
# data/test-00000-of-00001.parquet: 100% 6.11M/6.11M [00:00<00:00, 14.9MB/s]
# data/validation-00000-of-00001.parquet: 100% 6.32M/6.32M [00:00<00:00, 15.4MB/s]
# Generating train split: 100% 39905/39905 [00:00<00:00, 291568.96 examples/s]
# Generating test split: 100% 10003/10003 [00:00<00:00, 301561.32 examples/s]
# Generating validation split: 100% 10042/10042 [00:00<00:00, 305395.28 examples/s]
# Map: 100% 39905/39905 [00:07<00:00, 5562.16 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 5866.65 examples/s]
# piqa_train.parquet: 100% 2.64M/2.64M [00:00<00:00, 6.43MB/s]
# piqa_validation.parquet: 100% 300k/300k [00:00<00:00, 730kB/s]
# piqa_test.parquet: 100% 496k/496k [00:00<00:00, 1.21MB/s]
# Generating train split: 100% 16113/16113 [00:00<00:00, 930674.92 examples/s]
# Generating validation split: 100% 1838/1838 [00:00<00:00, 474700.17 examples/s]
# Generating test split: 100% 3084/3084 [00:00<00:00, 612928.05 examples/s]
# README.md: 11.2kB [00:00, 19.1MB/s]
# winogrande_xl/train-00000-of-00001.parqu(…): 100% 2.06M/2.06M [00:00<00:00, 5.01MB/s]
# winogrande_xl/test-00000-of-00001.parque(…): 100% 118k/118k [00:00<00:00, 287kB/s]
# winogrande_xl/validation-00000-of-00001.(…): 100% 85.9k/85.9k [00:00<00:00, 209kB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 1647526.33 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 468923.45 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 409066.52 examples/s]
# [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# README.md: 19.7kB [00:00, 34.4MB/s]
# boolq/train-00000-of-00001.parquet: 100% 3.85M/3.85M [00:00<00:00, 6.29MB/s]
# boolq/validation-00000-of-00001.parquet: 100% 1.31M/1.31M [00:00<00:00, 3.20MB/s]
# boolq/test-00000-of-00001.parquet: 100% 1.31M/1.31M [00:00<00:00, 2.14MB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 383040.16 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 301132.35 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 319765.92 examples/s]
# [Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# README.md: 35.3kB [00:00, 55.1MB/s]
# rte/train-00000-of-00001.parquet: 100% 584k/584k [00:00<00:00, 946kB/s]
# rte/validation-00000-of-00001.parquet: 100% 69.0k/69.0k [00:00<00:00, 113kB/s]
# rte/test-00000-of-00001.parquet: 100% 621k/621k [00:00<00:00, 1.52MB/s]
# Generating train split: 100% 2490/2490 [00:00<00:00, 381495.36 examples/s]
# Generating validation split: 100% 277/277 [00:00<00:00, 100001.91 examples/s]
# Generating test split: 100% 3000/3000 [00:00<00:00, 559364.84 examples/s]
# README.md: 9.06kB [00:00, 16.9MB/s]
# main/train-00000-of-00001.parquet: 100% 496k/496k [00:00<00:00, 812kB/s]
# main/validation-00000-of-00001.parquet: 100% 58.2k/58.2k [00:00<00:00, 142kB/s]
# main/test-00000-of-00001.parquet: 100% 55.5k/55.5k [00:00<00:00, 135kB/s]
# Generating train split: 100% 4957/4957 [00:00<00:00, 725391.28 examples/s]
# Generating validation split: 100% 500/500 [00:00<00:00, 169125.16 examples/s]
# Generating test split: 100% 500/500 [00:00<00:00, 179750.75 examples/s]
# README.md: 5.47kB [00:00, 13.8MB/s]
# default/test/default.parquet: 100% 1.16M/1.16M [00:00<00:00, 1.90MB/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 486751.99 examples/s]
# 100% 5153/5153 [00:13<00:00, 376.69it/s]
# 100% 500/500 [00:00<00:00, 569.49it/s]
# 100% 277/277 [00:00<00:00, 1800.00it/s]
# 100% 3270/3270 [00:01<00:00, 1807.86it/s]
# 100% 1267/1267 [00:00<00:00, 71584.99it/s]
# 100% 1838/1838 [00:02<00:00, 667.43it/s]
# 100% 10042/10042 [00:08<00:00, 1177.52it/s]
# 100% 1172/1172 [00:02<00:00, 476.04it/s]
# 100% 2376/2376 [00:04<00:00, 482.73it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Determined largest batch size: 22
# Running loglikelihood requests: 100% 74813/74813 [08:09<00:00, 152.72it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.73it/s]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 0iwvovhl (0.1s)
# wandb: ⣽ setting up run 0iwvovhl (0.1s)
# wandb: ⣾ setting up run 0iwvovhl (0.1s)
# wandb: ⣷ setting up run 0iwvovhl (0.1s)
# wandb: ⣯ setting up run 0iwvovhl (0.1s)
# wandb: ⣟ setting up run 0iwvovhl (0.7s)
# wandb: ⡿ setting up run 0iwvovhl (0.7s)
# wandb: ⢿ setting up run 0iwvovhl (0.7s)
# wandb: ⣻ setting up run 0iwvovhl (0.7s)
# wandb: ⣽ setting up run 0iwvovhl (0.7s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260326_083144-0iwvovhl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run float_model_Meta-Llama-3p1-8B_s42_20260326-081533
# wandb: ⭐️ View project at https://wandb.ai/tunjob/smartflip
# wandb: 🚀 View run at https://wandb.ai/tunjob/smartflip/runs/0iwvovhl
# wandb: ⢿ updating run metadata (0.6s)
# wandb: ⢿ uploading summary (0.0s)
# wandb: ⣻ updating run metadata (0.6s)
# wandb: ⣻ uploading summary (0.0s)
# wandb: ⣽ updating run metadata (0.6s)
# wandb: ⣽ uploading summary (0.0s)
# wandb: ⣾ updating run metadata (0.6s)
# wandb: ⣾ uploading summary (0.0s)
# wandb: ⣷ updating run metadata (1.1s)
# wandb: ⣷ uploading summary (0.5s)
# wandb: ⣯ updating run metadata (1.1s)
# wandb: ⣯ uploading summary (0.5s)
# wandb: ⣟ updating run metadata (1.1s)
# wandb: ⣟ uploading summary (0.5s)
# wandb: ⡿ updating run metadata (1.1s)
# wandb: ⡿ uploading summary (0.5s)
# wandb: ⢿ updating run metadata (1.1s)
# wandb: ⢿ uploading summary (0.5s)
# wandb: ⣻ uploading summary (1.0s)
# wandb: ⣻ uploading wandb-metadata.json 1.4KB/1.4KB (0.1s)
# wandb: ⣻ uploading requirements.txt 14.4KB/14.4KB (0.1s)
# wandb: ⣻ uploading wandb-summary.json 8.7KB/8.7KB (0.1s)
# wandb: ⣻ uploading config.yaml 3.6KB/3.6KB (0.1s)
# wandb: ⣽ uploading summary (1.0s)
# wandb: ⣽ uploading wandb-metadata.json 1.4KB/1.4KB (0.1s)
# wandb: ⣽ uploading requirements.txt 14.4KB/14.4KB (0.1s)
# wandb: ⣽ uploading wandb-summary.json 8.7KB/8.7KB (0.1s)
# wandb: ⣽ uploading config.yaml 3.6KB/3.6KB (0.1s)
# wandb: ⣾ uploading summary (1.0s)
# wandb: ⣾ uploading wandb-metadata.json 1.4KB/1.4KB (0.1s)
# wandb: ⣾ uploading requirements.txt 14.4KB/14.4KB (0.1s)
# wandb: ⣾ uploading wandb-summary.json 8.7KB/8.7KB (0.1s)
# wandb: ⣾ uploading config.yaml 3.6KB/3.6KB (0.1s)
# wandb: ⣷ uploading summary (1.0s)
# wandb: ⣷ uploading wandb-metadata.json 1.4KB/1.4KB (0.1s)
# wandb: ⣷ uploading requirements.txt 14.4KB/14.4KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 8.7KB/8.7KB (0.1s)
# wandb: ⣷ uploading config.yaml 3.6KB/3.6KB (0.1s)
# wandb: ⣯ uploading summary (1.0s)
# wandb: ⣯ uploading wandb-metadata.json 1.4KB/1.4KB (0.1s)
# wandb: ⣯ uploading requirements.txt 14.4KB/14.4KB (0.1s)
# wandb: ⣯ uploading wandb-summary.json 8.7KB/8.7KB (0.1s)
# wandb: ⣯ uploading config.yaml 3.6KB/3.6KB (0.1s)
# wandb: ⣟ uploading summary (1.5s)
# wandb: ⣟ uploading wandb-metadata.json 1.4KB/1.4KB (0.6s)
# wandb: ⣟ uploading requirements.txt 14.4KB/14.4KB (0.6s)
# wandb: ⣟ uploading wandb-summary.json 8.7KB/8.7KB (0.6s)
# wandb: ⡿ uploading summary (1.5s)
# wandb: ⡿ uploading wandb-metadata.json 1.4KB/1.4KB (0.6s)
# wandb: ⡿ uploading requirements.txt 14.4KB/14.4KB (0.6s)
# wandb: ⡿ uploading wandb-summary.json 8.7KB/8.7KB (0.6s)
# wandb: ⢿ uploading summary (1.5s)
# wandb: ⢿ uploading wandb-metadata.json 1.4KB/1.4KB (0.6s)
# wandb: ⢿ uploading requirements.txt 14.4KB/14.4KB (0.6s)
# wandb: ⢿ uploading wandb-summary.json 8.7KB/8.7KB (0.6s)
# wandb: ⣻ uploading summary (1.5s)
# wandb: ⣻ uploading wandb-metadata.json 1.4KB/1.4KB (0.6s)
# wandb: ⣻ uploading requirements.txt 14.4KB/14.4KB (0.6s)
# wandb: ⣻ uploading wandb-summary.json 8.7KB/8.7KB (0.6s)
# wandb: ⣽ uploading summary (1.5s)
# wandb: ⣽ uploading wandb-metadata.json 1.4KB/1.4KB (0.6s)
# wandb: ⣽ uploading requirements.txt 14.4KB/14.4KB (0.6s)
# wandb: ⣽ uploading wandb-summary.json 8.7KB/8.7KB (0.6s)
# wandb: ⣾ uploading summary (2.0s)
# wandb: ⣾ uploading wandb-metadata.json 1.4KB/1.4KB (1.1s)
# wandb: ⣾ uploading requirements.txt 14.4KB/14.4KB (1.1s)
# wandb: ⣾ uploading wandb-summary.json 8.7KB/8.7KB (1.1s)
# wandb: ⣷ uploading summary (2.0s)
# wandb: ⣷ uploading wandb-metadata.json 1.4KB/1.4KB (1.1s)
# wandb: ⣷ uploading requirements.txt 14.4KB/14.4KB (1.1s)
# wandb: ⣷ uploading wandb-summary.json 8.7KB/8.7KB (1.1s)
# wandb: ⣯ uploading summary (2.0s)
# wandb: ⣯ uploading wandb-metadata.json 1.4KB/1.4KB (1.1s)
# wandb: ⣯ uploading requirements.txt 14.4KB/14.4KB (1.1s)
# wandb: ⣯ uploading wandb-summary.json 8.7KB/8.7KB (1.1s)
# wandb: ⣟ uploading summary (2.0s)
# wandb: ⣟ uploading wandb-metadata.json 1.4KB/1.4KB (1.1s)
# wandb: ⣟ uploading requirements.txt 14.4KB/14.4KB (1.1s)
# wandb: ⣟ uploading wandb-summary.json 8.7KB/8.7KB (1.1s)
# wandb: ⡿ uploading summary (2.0s)
# wandb: ⡿ uploading wandb-metadata.json 1.4KB/1.4KB (1.1s)
# wandb: ⡿ uploading requirements.txt 14.4KB/14.4KB (1.1s)
# wandb: ⡿ uploading wandb-summary.json 8.7KB/8.7KB (1.1s)
# wandb: ⢿ uploading summary (2.5s)
# wandb: ⣻ uploading summary (2.5s)
# wandb: ⣽ uploading summary (2.5s)
# wandb: ⣾ uploading summary (2.5s)
# wandb: ⣷ uploading summary (2.5s)
# wandb: ⣯ uploading summary (3.0s)
# wandb: ⣟ uploading summary (3.0s)
# wandb: ⡿ uploading summary (3.0s)
# wandb: ⢿ uploading summary (3.0s)
# wandb: ⣻ uploading summary (3.0s)
# wandb: ⣽ uploading history steps 0-0, summary (0.2s)
# wandb: ⣾ uploading history steps 0-0, summary (0.2s)
# wandb: ⣷ uploading history steps 0-0, summary (0.2s)
# wandb: ⣯ uploading history steps 0-0, summary (0.2s)
# wandb: ⣟ uploading history steps 0-0, summary (0.2s)
# wandb: ⡿ uploading history steps 0-0, summary (0.7s)
# wandb: ⢿ uploading history steps 0-0, summary (0.7s)
# wandb: ⣻ uploading history steps 0-0, summary (0.7s)
# wandb: ⣽ uploading history steps 0-0, summary (0.7s)
# wandb: ⣾ uploading history steps 0-0, summary (0.7s)
# wandb: ⣷ uploading history steps 0-0, summary (1.2s)
# wandb: ⣯ uploading history steps 0-0, summary (1.2s)
# wandb: ⣟ uploading history steps 0-0, summary (1.2s)
# wandb: ⡿ uploading history steps 0-0, summary (1.2s)
# wandb: ⢿ uploading history steps 0-0, summary (1.2s)
# wandb: ⣻ uploading history steps 0-0, summary (1.7s)
# wandb: ⣽ uploading history steps 0-0, summary (1.7s)
# wandb: ⣾ uploading history steps 0-0, summary (1.7s)
# wandb: ⣷ uploading history steps 0-0, summary (1.7s)
# wandb: ⣯ uploading history steps 0-0, summary (1.7s)
# wandb: ⣟ uploading history steps 0-0, summary (2.2s)
# wandb: ⡿ uploading history steps 0-0, summary (2.2s)
# wandb: ⢿ uploading history steps 0-0, summary (2.2s)
# wandb: ⣻ uploading history steps 0-0, summary (2.2s)
# wandb: ⣽ uploading history steps 0-0, summary (2.2s)
# wandb: ⣾ uploading history steps 0-0, summary (2.7s)
# wandb: ⣷ uploading history steps 0-0, summary (2.7s)
# wandb: ⣯ uploading history steps 0-0, summary (2.7s)
# wandb: ⣟ uploading history steps 0-0, summary (2.7s)
# wandb: ⡿ uploading history steps 0-0, summary (2.7s)
# wandb: ⢿ uploading history steps 0-0, summary (3.2s)
# wandb: ⣻ uploading history steps 0-0, summary (3.2s)
# wandb:
# wandb: Run history:
# wandb:                 lm_eval/float_model/raw/config/bootstrap_iters ▁
# wandb:                    lm_eval/float_model/raw/config/fewshot_seed ▁
# wandb:            lm_eval/float_model/raw/config/model_num_parameters ▁
# wandb:                      lm_eval/float_model/raw/config/numpy_seed ▁
# wandb:                     lm_eval/float_model/raw/config/random_seed ▁
# wandb:                      lm_eval/float_model/raw/config/torch_seed ▁
# wandb: lm_eval/float_model/raw/configs/arc_challenge/metadata/version ▁
# wandb:      lm_eval/float_model/raw/configs/arc_challenge/num_fewshot ▁
# wandb:          lm_eval/float_model/raw/configs/arc_challenge/repeats ▁
# wandb:      lm_eval/float_model/raw/configs/arc_easy/metadata/version ▁
# wandb:                                                           +126 ...
# wandb:
# wandb: Run summary:
# wandb:                 lm_eval/float_model/raw/config/bootstrap_iters 100000
# wandb:                    lm_eval/float_model/raw/config/fewshot_seed 1234
# wandb:            lm_eval/float_model/raw/config/model_num_parameters 8030261248
# wandb:                      lm_eval/float_model/raw/config/numpy_seed 1234
# wandb:                     lm_eval/float_model/raw/config/random_seed 0
# wandb:                      lm_eval/float_model/raw/config/torch_seed 1234
# wandb: lm_eval/float_model/raw/configs/arc_challenge/metadata/version 1
# wandb:      lm_eval/float_model/raw/configs/arc_challenge/num_fewshot 0
# wandb:          lm_eval/float_model/raw/configs/arc_challenge/repeats 1
# wandb:      lm_eval/float_model/raw/configs/arc_easy/metadata/version 1
# wandb:                                                           +130 ...
# wandb:
# wandb: 🚀 View run float_model_Meta-Llama-3p1-8B_s42_20260326-081533 at: https://wandb.ai/tunjob/smartflip/runs/0iwvovhl
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/smartflip
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260326_083144-0iwvovhl/logs
#
# Saved evaluation results to results/eval/float_model_Meta-Llama-3p1-8B_s42_20260326-081533.json
# ==> raw_quantize :: meta-llama/Meta-Llama-3.1-8B
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 291/291 [00:04<00:00, 72.43it/s, Materializing param=model.norm.weight]
#
# [C4 Calibration Data - Optimized]
#   Samples: 128
#   Sequence length: 2048 tokens
#   Seed: 42
#   Loading from cache: data/cache/calibration/c4_calib_n128_len2048_seed42_tensorsFalse.pkl
#
# [AWQ Quantizer XL Initialized]
#   Config: {'bits': 4, 'n_grid': 20, 'group_size': 128, 'max_tokens_per_sample': 2048, 'layer_batch_size': 16, 'lmhead_chunks': 4}
#   Post correction: none
#
# ================================================================================
# Batched Sequential Quantization
# ================================================================================
#   Strategy: Process 16 layers per batch
#   Initial System RAM: 3.6%
#
# [Batch 1/15] Layers 0-15
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 2/15] Layers 16-31
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 3/15] Layers 32-47
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 4/15] Layers 48-63
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 5/15] Layers 64-79
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 6/15] Layers 80-95
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 7/15] Layers 96-111
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 8/15] Layers 112-127
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 9/15] Layers 128-143
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 10/15] Layers 144-159
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 11/15] Layers 160-175
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 12/15] Layers 176-191
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 13/15] Layers 192-207
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 14/15] Layers 208-223
#   Calibrating 16 layers...
#   Quantizing 16 layers...
#
# [Batch 15/15] Layers 224-224
#   Calibrating 1 layers...
#   Quantizing 1 layers...
#
# ================================================================================
# Quantization Complete
#   Total layers quantized: 225/225
# ================================================================================
# Writing model shards: 100% 1/1 [01:00<00:00, 60.10s/it]
#
# Saved awq_raw model to results/models/awq_raw/awq_raw_Meta-Llama-3p1-8B_b4_g128_s42_20260326-083719
#
# Evaluating raw_quantize on WikiText-2...
# Loading weights: 100% 291/291 [00:40<00:00,  7.23it/s, Materializing param=model.norm.weight]
# Token indices sequence length is longer than the specified maximum sequence length for this model (288936 > 131072). Running this sequence through the model will result in indexing errors
#
# Evaluating raw_quantize on C4...
# Loading weights: 100% 291/291 [00:16<00:00, 17.32it/s, Materializing param=model.norm.weight]
# Token indices sequence length is longer than the specified maximum sequence length for this model (291380 > 131072). Running this sequence through the model will result in indexing errors
#
# Running lm-eval for raw_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# Loading weights: 100% 291/291 [00:15<00:00, 18.96it/s, Materializing param=model.norm.weight]
# [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# [Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# [Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 5153/5153 [00:13<00:00, 377.69it/s]
# 100% 500/500 [00:00<00:00, 532.79it/s]
# 100% 277/277 [00:00<00:00, 1735.29it/s]
# 100% 3270/3270 [00:01<00:00, 1745.08it/s]
# 100% 1267/1267 [00:00<00:00, 64123.65it/s]
# 100% 1838/1838 [00:02<00:00, 638.75it/s]
# 100% 10042/10042 [00:08<00:00, 1177.07it/s]
# 100% 1172/1172 [00:02<00:00, 461.43it/s]
# 100% 2376/2376 [00:05<00:00, 467.67it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Determined largest batch size: 22
# Running loglikelihood requests:  27% 19977/74813 [03:58<07:45, 117.70it/s]
